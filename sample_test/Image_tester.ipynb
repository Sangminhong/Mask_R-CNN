# %%
import torch
import matplotlib
from PIL import Image
import cv2
import os
import numpy as np

# %%
base_dir = os.path.abspath("/mnt/hdd2/COCO")
root=os.path.join(base_dir, "train2017")
ex_img = os.path.join(root,"000000188958.jpg")
ann_path = os.path.join(base_dir,"annotations","instances_train2017.json")

# %%
Image.open(ex_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F71D1793510>

# %%
ex2_img = os.path.join(root,"000000188972.jpg")
im=Image.open(ex2_img).convert('RGB')
im
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7F71D17A23D0>

# %%
crop = im.crop((11,45,200,350))
crop
# Out:
# <PIL.Image.Image image mode=RGB size=189x305 at 0x7F71D179F5D0>

# %%
num_img = np.array(im)
num_img2= np.array(crop)
print(num_img.shape)
print(num_img2.shape)
# Out:
# (427, 640, 3)
# (305, 189, 3)
